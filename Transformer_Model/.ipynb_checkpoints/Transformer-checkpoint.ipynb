# %%
import numpy as np
import os
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import TensorBoard
import time
# Out:
# C:\Users\MONSTER\anaconda3\envs\image\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\MONSTER\anaconda3\envs\image\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\MONSTER\anaconda3\envs\image\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
DIRECTORY = r"D:/Datasets/BGYF_Dataset"
CATEGORIES = os.listdir(DIRECTORY)
CATEGORY_SIZE = len(CATEGORIES)
class_types  = CATEGORIES
IMG_SIZE = 64
patch_size=4

# %%
# grab the list of images in our dataset directory, then initialize the list of data (i.e., images) and class images
data = []
labels = []

for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    filelist = os.listdir(path)
    for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
        if not(fichier.endswith(".jpg")):
            filelist.remove(fichier)
    
    for img in filelist:
        img_path = os.path.join(path, img)
        image = load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
        
        image = img_to_array(image)
        
        data.append(image)
        labels.append(category)

# %%
category
# Out:
# 'H'

# %%
# perform one-hot encoding on the labels
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# define example
values = array(labels)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
labels = tf.keras.utils.to_categorical(integer_encoded, num_classes=2, dtype='uint8')


data = np.array(data, dtype='uint8')
labels = np.array(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=4)

# %%
training_data = tf.data.Dataset.from_tensor_slices((trainX, trainY))
validation_data = tf.data.Dataset.from_tensor_slices((testX, testY))

# %%
autotune = tf.data.AUTOTUNE
train_data_batches = training_data.shuffle(buffer_size=160, seed=4).batch(16).prefetch(buffer_size=autotune)
valid_data_batches = validation_data.shuffle(buffer_size=40, seed=4).batch(4).prefetch(buffer_size=autotune)

train_ds = (training_data.shuffle(160, seed=4).batch(16).prefetch(autotune))
valid_ds = (validation_data.shuffle(40, seed=4).batch(4).prefetch(autotune))

# %%
print ('train im and label types: ', type(trainX), type(trainY))
# Out:
# train im and label types:  <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
print ('check types; ', type(training_data), type(validation_data))
# Out:
# check types;  <class 'tensorflow.python.data.ops.dataset_ops.TensorSliceDataset'> <class 'tensorflow.python.data.ops.dataset_ops.TensorSliceDataset'>

# %%
class generate_patch(layers.Layer):
    def __init__(self, patch_size):
        super(generate_patch, self).__init__()
        self.patch_size = patch_size
    
    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(images=images, 
                                           sizes=[1, self.patch_size, self.patch_size, 1], 
                                           strides=[1, self.patch_size, self.patch_size, 1], rates=[1, 1, 1, 1], padding="VALID")
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims]) #here shape is (batch_size, num_patches, patch_h*patch_w*c) 
        return patches

# %%
from itertools import islice, count

train_iter_7im, train_iter_7label = next(islice(training_data, 7, None)) # access the 7th element from the iterator



train_iter_7im = tf.expand_dims(train_iter_7im, 0)
train_iter_7label = train_iter_7label.numpy()

print('check shapes: ', train_iter_7im.shape) 

######################
# num patches (W * H) /P^2 where W, H are from original image, P is patch dim. 
# Original image (H * W * C), patch N * P*P *C, N num patches
######################
generate_patch_layer = generate_patch(patch_size=patch_size)
patches = generate_patch_layer(train_iter_7im)

print ('patch per image and patches shape: ', patches.shape[1], '\n', patches.shape)



def render_image_and_patches(image, patches):
    plt.figure(figsize=(6, 6))
    plt.imshow(tf.cast(image[0], tf.uint8))
    plt.xlabel(class_types [np.argmax(train_iter_7label)], fontsize=13)
    n = int(np.sqrt(patches.shape[1]))
    plt.figure(figsize=(6, 6))
    #plt.suptitle(f"Image Patches", size=13)
    for i, patch in enumerate(patches[0]):
        ax = plt.subplot(n, n, i+1)
        patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
        ax.imshow(patch_img.numpy().astype("uint8"))
        ax.axis('off')    

        


render_image_and_patches(train_iter_7im, patches)
# Out:
# check shapes:  (1, 64, 64, 3)
# patch per image and patches shape:  256
#  (1, 256, 48)

# %%
### Positonal Encoding Layer

class PatchEncode_Embed(layers.Layer):
    '''
    2 steps happen here
    1. flatten the patches 
    2. Map to dim D; patch embeddings  
    '''
    def __init__(self, num_patches, projection_dim):
        super(PatchEncode_Embed, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)# activation = linear
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim)
    
    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
patch_encoder = PatchEncode_Embed(256, 256)(patches)
print (tf.shape(patch_encoder))
# Out:
# tf.Tensor([  1 256 256], shape=(3,), dtype=int32)

# %%
class generate_patch_conv(layers.Layer):
    '''
    this is an example to generate conv patches comparable with the image patches
    generated using tf extract image patches. This wasn't the original implementation, specially 
    the number of filters in the conv layer has nothing to do with patch size. It must be same as
    hidden dim (query/key dim) in relation to multi-head attention layer.       
    '''
    def __init__(self, patch_size):
        super(generate_patch_conv, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = layers.Conv2D(self.patch_size*self.patch_size*3, self.patch_size, self.patch_size, padding='valid')(images)

        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches  

class generate_patch_conv_orgPaper(layers.Layer):
    '''
    original implementation, 
    hidden size = query/key dim in multi head attention layer later. 
    '''
    def __init__(self, patch_size, hidden_size):
        super(generate_patch_conv_orgPaper, self).__init__()
        self.patch_size = patch_size
        self.hidden_size = hidden_size

    def call(self, images):
        patches = layers.Conv2D(self.hidden_size, self.patch_size, self.patch_size, padding='valid', name='Embedding')(images) 
        # kernels and strides = patch size
        # the weights of the convolutional layer will be learned. 
        rows_axis, cols_axis = (1, 2) # channels last images
        #if channels_last:
            #rows_axis, cols_axis = (2, 3) # for channels last
            # x = tf.transpose(patches, perm=[0, 2, 3, 1]) # do this for channels_first
        seq_len = (images.shape[rows_axis] // patch_size) * (images.shape[cols_axis] // patch_size)
        x = tf.reshape(patches, [-1, seq_len, self.hidden_size])
        return x

def generate_patch_conv_orgPaper_f(patch_size, hidden_size, inputs):
    patches = layers.Conv2D(filters=hidden_size, kernel_size=patch_size, strides=patch_size, padding='valid')(inputs)
    row_axis, col_axis = (1, 2) # channels last images
    seq_len = (inputs.shape[row_axis] // patch_size) * (inputs.shape[col_axis] // patch_size)
    x = tf.reshape(patches, [-1, seq_len, hidden_size])
    return x




train_iter_7im = tf.cast(train_iter_7im, dtype=tf.float16)
generate_patch_conv_layer = generate_patch_conv(patch_size=patch_size)
patches_conv = generate_patch_conv_layer(train_iter_7im)


print ('patch per image and patches shape: ', patches_conv.shape[1], '\n', patches_conv.shape)    

generate_patch_conv_orgPaper_layer = generate_patch_conv_orgPaper(patch_size=patch_size, hidden_size=64)
patches_conv_org = generate_patch_conv_orgPaper_layer(train_iter_7im)

hidden_size=64
patches_conv_org_f = generate_patch_conv_orgPaper_f(patch_size, hidden_size, train_iter_7im)

print ('patch per image and patches shape: ', patches_conv_org.shape[1], '\n', patches_conv_org.shape)
print ('patch per image and patches shape: ', patches_conv_org_f.shape[1], '\n', patches_conv_org_f.shape)
# Out:
# patch per image and patches shape:  256
#  (1, 256, 48)
# patch per image and patches shape:  256
#  (1, 256, 64)
# patch per image and patches shape:  256
#  (1, 256, 64)

# %%
def render_image_and_patches(image, patches):
    plt.figure(figsize=(6, 6))
    plt.imshow(tf.cast(image[0], tf.uint8))
    plt.xlabel(class_types [np.argmax(train_iter_7label)], fontsize=13)
    n = int(np.sqrt(patches.shape[1]))
    plt.figure(figsize=(6, 6))
    #plt.suptitle(f"Image Patches", size=13)
    for i, patch in enumerate(patches[0]):
        ax = plt.subplot(n, n, i+1)
        patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
        ax.imshow(patch_img.numpy().astype("uint8"))
        ax.axis('off')

render_image_and_patches(train_iter_7im, patches_conv)

# %%
### Positonal Encoding Layer

class AddPositionEmbs(layers.Layer):
    """Adds (optionally learned) positional embeddings to the inputs."""

    def __init__(self, posemb_init=None, **kwargs):
        super().__init__(**kwargs)
        self.posemb_init = posemb_init
        #posemb_init=tf.keras.initializers.RandomNormal(stddev=0.02), name='posembed_input') # used in original code

    def build(self, inputs_shape):
        pos_emb_shape = (1, inputs_shape[1], inputs_shape[2])
        self.pos_embedding = self.add_weight('pos_embedding', pos_emb_shape, initializer=self.posemb_init)

    def call(self, inputs, inputs_positions=None):
        # inputs.shape is (batch_size, seq_len, emb_dim).
        pos_embedding = tf.cast(self.pos_embedding, inputs.dtype)

        return inputs + pos_embedding


pos_embed_layer = AddPositionEmbs(posemb_init=tf.keras.initializers.RandomNormal(stddev=0.02))
embedded_inp = pos_embed_layer(patches_conv_org)

print ('embedded input shape: ', embedded_inp.shape)
# Out:
# embedded input shape:  (1, 256, 64)

# %%
def mlp_block_f(mlp_dim, inputs):
    x = layers.Dense(units=mlp_dim, activation=tf.nn.gelu)(inputs)
    x = layers.Dropout(rate=0.01)(x) # dropout rate is from original paper,
    x = layers.Dense(units=inputs.shape[-1], activation=tf.nn.gelu)(x)
    x = layers.Dropout(rate=0.01)(x)
    return x




def Encoder1Dblock_f(num_heads, mlp_dim, inputs):
    x = layers.LayerNormalization(dtype=inputs.dtype)(inputs)
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1], dropout=0.01)(x, x) # self attention multi-head, dropout_rate is from original implementation
    x = layers.Add()([x, inputs]) # 1st residual part 
  
    y = layers.LayerNormalization(dtype=x.dtype)(x)
    y = mlp_block_f(mlp_dim, y)
    y_1 = layers.Add()([y, x]) #2nd residual part 
    return y_1


#########################################
# test with the embeddings as input
#########################################
# Encoder1Dblock_layer = Encoder1Dblock(num_heads=4, mlp_dim=32)
# Encoder1Dblock_layer_out = Encoder1Dblock_layer(embedded_inp)
Encoder1Dblock_layer_out_f = Encoder1Dblock_f(4, 32, embedded_inp)

# print ('output shape of Encoder block when inputs are the embeddings: ', Encoder1Dblock_layer_out.shape)
print ('output shape of Encoder block when inputs are the embeddings: ', Encoder1Dblock_layer_out_f.shape)
# Out:
# output shape of Encoder block when inputs are the embeddings:  (1, 256, 64)

# %%
### augment train but not test 

rescale_layer = tf.keras.Sequential([layers.experimental.preprocessing.Rescaling(1./255)])

data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2), 
    layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3)),
    layers.experimental.preprocessing.RandomTranslation(0.3, 0.3, fill_mode='reflect', interpolation='bilinear',)
])


train_ds = (training_data.shuffle(160).batch(16).map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=autotune).prefetch(autotune))
valid_ds = (validation_data.shuffle(40).batch(4).prefetch(autotune))

# %%
def Encoder_f(num_layers, mlp_dim, num_heads, inputs):
    x = AddPositionEmbs(posemb_init=tf.keras.initializers.RandomNormal(stddev=0.02), name='posembed_input')(inputs)
    x = layers.Dropout(rate=0.02)(x)
    for _ in range(num_layers):
        x = Encoder1Dblock_f(num_heads, mlp_dim, x)

    encoded = layers.LayerNormalization(name='encoder_norm')(x)
    return encoded




######################################
# hyperparameter section 
###################################### 
transformer_layers = 6
hidden_size = 64
num_heads = 4
mlp_dim = 128

######################################




def build_ViT():
    inputs = layers.Input(shape=trainX.shape[1:])
    # rescaling (normalizing pixel val between 0 and 1)
    rescale = rescale_layer(inputs)
    # augmentation 
    # augmented = data_augmentation(rescale)
    # generate patches with conv layer
    patches = generate_patch_conv_orgPaper_f(patch_size, hidden_size, rescale)

    ######################################
    # ready for the transformer blocks
    ######################################
    encoder_out = Encoder_f(transformer_layers, mlp_dim, num_heads, patches)  

    #####################################
    #  final part (mlp to classification)
    #####################################
    #encoder_out_rank = int(tf.experimental.numpy.ndim(encoder_out))
    im_representation = tf.reduce_mean(encoder_out, axis=1)  # (1,) or (1,2)

    logits = layers.Dense(units=len(class_types), name='head', kernel_initializer=tf.keras.initializers.zeros)(im_representation) # !!! important !!! activation is linear 

    final_model = tf.keras.Model(inputs = inputs, outputs = logits)
    return final_model



ViT_model = build_ViT()
ViT_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  sequential (Sequential)        (None, 64, 64, 3)    0           ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 64)   3136        ['sequential[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 256, 64)      0           ['conv2d_2[0][0]']
#
#  posembed_input (AddPositionEmb  (None, 256, 64)     16384       ['tf.reshape[0][0]']
#  s)
#
#  dropout_3 (Dropout)            (None, 256, 64)      0           ['posembed_input[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 256, 64)     128         ['dropout_3[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 256, 64)     66368       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 256, 64)      0           ['multi_head_attention_1[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 256, 64)     128         ['add_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 256, 128)     8320        ['layer_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 256, 128)     0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 256, 64)      8256        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 256, 64)      0           ['dense_4[0][0]']
#
#  add_3 (Add)                    (None, 256, 64)      0           ['dropout_5[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 256, 64)     128         ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 256, 64)     66368       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 256, 64)      0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 256, 64)     128         ['add_4[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 256, 128)     8320        ['layer_normalization_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 256, 128)     0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 256, 64)      8256        ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 256, 64)      0           ['dense_6[0][0]']
#
#  add_5 (Add)                    (None, 256, 64)      0           ['dropout_7[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 256, 64)     128         ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 256, 64)     66368       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 256, 64)      0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 256, 64)     128         ['add_6[0][0]']
#  rmalization)
#
#  dense_7 (Dense)                (None, 256, 128)     8320        ['layer_normalization_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256, 128)     0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 256, 64)      8256        ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 256, 64)      0           ['dense_8[0][0]']
#
#  add_7 (Add)                    (None, 256, 64)      0           ['dropout_9[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 256, 64)     128         ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 256, 64)     66368       ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 256, 64)      0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 256, 64)     128         ['add_8[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (None, 256, 128)     8320        ['layer_normalization_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 256, 128)     0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 256, 64)      8256        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 256, 64)      0           ['dense_10[0][0]']
#
#  add_9 (Add)                    (None, 256, 64)      0           ['dropout_11[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 256, 64)     128         ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 256, 64)     66368       ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 256, 64)      0           ['multi_head_attention_5[0][0]',
#                                                                   'add_9[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 256, 64)     128         ['add_10[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (None, 256, 128)     8320        ['layer_normalization_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 256, 128)     0           ['dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 256, 64)      8256        ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 256, 64)      0           ['dense_12[0][0]']
#
#  add_11 (Add)                   (None, 256, 64)      0           ['dropout_13[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 256, 64)     128         ['add_11[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 256, 64)     66368       ['layer_normalization_12[0][0]',
#  eadAttention)                                                    'layer_normalization_12[0][0]']
#
#  add_12 (Add)                   (None, 256, 64)      0           ['multi_head_attention_6[0][0]',
#                                                                   'add_11[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 256, 64)     128         ['add_12[0][0]']
#  ormalization)
#
#  dense_13 (Dense)               (None, 256, 128)     8320        ['layer_normalization_13[0][0]']
#
#  dropout_14 (Dropout)           (None, 256, 128)     0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 256, 64)      8256        ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 256, 64)      0           ['dense_14[0][0]']
#
#  add_13 (Add)                   (None, 256, 64)      0           ['dropout_15[0][0]',
#                                                                   'add_12[0][0]']
#
#  encoder_norm (LayerNormalizati  (None, 256, 64)     128         ['add_13[0][0]']
#  on)
#
#  tf.math.reduce_mean (TFOpLambd  (None, 64)          0           ['encoder_norm[0][0]']
#  a)
#
#  head (Dense)                   (None, 2)            130         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 518,978
# Trainable params: 518,978
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(ViT_model, rankdir='TB')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 2), dtype=tf.uint8, name=None))>

# %%
len(valid_ds)
# Out:
# 10

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 2), dtype=tf.uint8, name=None))>

# %%
# Tensorboard
NAME = "{}-{}-{}-{}".format('Transformer', int(time.time()), IMG_SIZE, patch_size)
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))


### model 

ViT_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-4), 
                  loss = tf.keras.losses.BinaryCrossentropy(from_logits=True), 
                  metrics=[tf.keras.metrics.BinaryAccuracy(name="accuracy")]) 
#tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")],) 
# from logits = True, because Dense layer has linear activation


reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.8,
                              patience=5, min_lr=1e-8, verbose=1)


ViT_Train = ViT_model.fit(train_ds, 
                        epochs = 200, 
                        validation_data=valid_ds, callbacks=[reduce_lr,tensorboard])
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer AddPositionEmbs has arguments ['self', 'posemb_init']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/200
# 10/10 [==============================] - 11s 653ms/step - loss: 0.6913 - accuracy: 0.5000 - val_loss: 0.6826 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 2/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.6762 - accuracy: 0.5000 - val_loss: 0.6751 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 3/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.6593 - accuracy: 0.5000 - val_loss: 0.6633 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 4/200
# 10/10 [==============================] - 5s 472ms/step - loss: 0.6692 - accuracy: 0.5000 - val_loss: 0.7163 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 5/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.7036 - accuracy: 0.5000 - val_loss: 0.6822 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 6/200
# 10/10 [==============================] - 5s 472ms/step - loss: 0.6723 - accuracy: 0.5000 - val_loss: 0.6346 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 7/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.6148 - accuracy: 0.5000 - val_loss: 0.6462 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 8/200
# 10/10 [==============================] - 5s 473ms/step - loss: 0.6268 - accuracy: 0.5000 - val_loss: 0.5513 - val_accuracy: 0.6750 - lr: 2.0000e-04
# Epoch 9/200
# 10/10 [==============================] - 5s 472ms/step - loss: 0.5835 - accuracy: 0.7344 - val_loss: 0.6286 - val_accuracy: 0.6625 - lr: 2.0000e-04
# Epoch 10/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.6234 - accuracy: 0.6844 - val_loss: 0.5172 - val_accuracy: 0.8125 - lr: 2.0000e-04
# Epoch 11/200
# 10/10 [==============================] - 5s 476ms/step - loss: 0.5342 - accuracy: 0.8094 - val_loss: 0.4911 - val_accuracy: 0.8500 - lr: 2.0000e-04
# Epoch 12/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.5084 - accuracy: 0.8281 - val_loss: 0.6155 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 13/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.6128 - accuracy: 0.6938 - val_loss: 0.4613 - val_accuracy: 0.8625 - lr: 2.0000e-04
# Epoch 14/200
# 10/10 [==============================] - 5s 473ms/step - loss: 0.4872 - accuracy: 0.8250 - val_loss: 0.5029 - val_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 15/200
# 10/10 [==============================] - 5s 473ms/step - loss: 0.5304 - accuracy: 0.7719 - val_loss: 0.4002 - val_accuracy: 0.9125 - lr: 2.0000e-04
# Epoch 16/200
# 10/10 [==============================] - 5s 474ms/step - loss: 0.4948 - accuracy: 0.8062 - val_loss: 0.4049 - val_accuracy: 0.9125 - lr: 2.0000e-04
# Epoch 17/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.4447 - accuracy: 0.8438 - val_loss: 0.3364 - val_accuracy: 0.9375 - lr: 2.0000e-04
# Epoch 18/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.4394 - accuracy: 0.8438 - val_loss: 0.3150 - val_accuracy: 0.9375 - lr: 2.0000e-04
# Epoch 19/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.5260 - accuracy: 0.7750 - val_loss: 0.7284 - val_accuracy: 0.6125 - lr: 2.0000e-04
# Epoch 20/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.5079 - accuracy: 0.7875 - val_loss: 0.3010 - val_accuracy: 0.9625 - lr: 2.0000e-04
# Epoch 21/200
# 10/10 [==============================] - 5s 472ms/step - loss: 0.3804 - accuracy: 0.8844 - val_loss: 0.3248 - val_accuracy: 0.9250 - lr: 2.0000e-04
# Epoch 22/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.4437 - accuracy: 0.8313 - val_loss: 0.3176 - val_accuracy: 0.9250 - lr: 2.0000e-04
# Epoch 23/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.5105 - accuracy: 0.7937 - val_loss: 0.6602 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 24/200
# 10/10 [==============================] - 5s 474ms/step - loss: 0.4508 - accuracy: 0.8281 - val_loss: 0.3442 - val_accuracy: 0.9000 - lr: 2.0000e-04
# Epoch 25/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8625
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00015999999595806003.
# 10/10 [==============================] - 5s 470ms/step - loss: 0.3987 - accuracy: 0.8625 - val_loss: 0.5562 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 26/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.4115 - accuracy: 0.8562 - val_loss: 0.4498 - val_accuracy: 0.8250 - lr: 1.6000e-04
# Epoch 27/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.3296 - accuracy: 0.9000 - val_loss: 0.2653 - val_accuracy: 0.9500 - lr: 1.6000e-04
# Epoch 28/200
# 10/10 [==============================] - 5s 473ms/step - loss: 0.3068 - accuracy: 0.9156 - val_loss: 0.3311 - val_accuracy: 0.9000 - lr: 1.6000e-04
# Epoch 29/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.2719 - accuracy: 0.9344 - val_loss: 0.2609 - val_accuracy: 0.9375 - lr: 1.6000e-04
# Epoch 30/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2641 - accuracy: 0.9375 - val_loss: 0.2953 - val_accuracy: 0.9250 - lr: 1.6000e-04
# Epoch 31/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2696 - accuracy: 0.9312 - val_loss: 0.2193 - val_accuracy: 0.9500 - lr: 1.6000e-04
# Epoch 32/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.2478 - accuracy: 0.9406 - val_loss: 0.2724 - val_accuracy: 0.9250 - lr: 1.6000e-04
# Epoch 33/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.2252 - accuracy: 0.9531 - val_loss: 0.3007 - val_accuracy: 0.9125 - lr: 1.6000e-04
# Epoch 34/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.2673 - accuracy: 0.9250 - val_loss: 0.4774 - val_accuracy: 0.8250 - lr: 1.6000e-04
# Epoch 35/200
# 10/10 [==============================] - 5s 472ms/step - loss: 0.2582 - accuracy: 0.9312 - val_loss: 0.1309 - val_accuracy: 1.0000 - lr: 1.6000e-04
# Epoch 36/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.2791 - accuracy: 0.9187 - val_loss: 0.6165 - val_accuracy: 0.7250 - lr: 1.6000e-04
# Epoch 37/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2784 - accuracy: 0.9125 - val_loss: 0.1467 - val_accuracy: 0.9875 - lr: 1.6000e-04
# Epoch 38/200
# 10/10 [==============================] - 5s 474ms/step - loss: 0.2215 - accuracy: 0.9438 - val_loss: 0.3103 - val_accuracy: 0.8875 - lr: 1.6000e-04
# Epoch 39/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2006 - accuracy: 0.9500 - val_loss: 0.1847 - val_accuracy: 0.9500 - lr: 1.6000e-04
# Epoch 40/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2053 - accuracy: 0.9375
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
# 10/10 [==============================] - 5s 471ms/step - loss: 0.2053 - accuracy: 0.9375 - val_loss: 0.1308 - val_accuracy: 0.9875 - lr: 1.6000e-04
# Epoch 41/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2297 - accuracy: 0.9250 - val_loss: 0.3099 - val_accuracy: 0.8625 - lr: 1.2800e-04
# Epoch 42/200
# 10/10 [==============================] - 5s 470ms/step - loss: 0.2035 - accuracy: 0.9469 - val_loss: 0.3529 - val_accuracy: 0.8500 - lr: 1.2800e-04
# Epoch 43/200
# 10/10 [==============================] - 5s 471ms/step - loss: 0.1908 - accuracy: 0.9500 - val_loss: 0.1689 - val_accuracy: 0.9375 - lr: 1.2800e-04
# Epoch 44/200
# 10/10 [==============================] - 5s 469ms/step - loss: 0.1814 - accuracy: 0.9469 - val_loss: 0.2109 - val_accuracy: 0.9125 - lr: 1.2800e-04
# Epoch 45/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9594
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00010239999974146486.
# 10/10 [==============================] - 5s 474ms/step - loss: 0.1724 - accuracy: 0.9594 - val_loss: 0.1828 - val_accuracy: 0.9375 - lr: 1.2800e-04
# Epoch 46/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1682 - accuracy: 0.9563 - val_loss: 0.3716 - val_accuracy: 0.8375 - lr: 1.0240e-04
# Epoch 47/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1531 - accuracy: 0.9688 - val_loss: 0.2094 - val_accuracy: 0.9375 - lr: 1.0240e-04
# Epoch 48/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1389 - accuracy: 0.9750 - val_loss: 0.4604 - val_accuracy: 0.8375 - lr: 1.0240e-04
# Epoch 49/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1404 - accuracy: 0.9750 - val_loss: 0.3224 - val_accuracy: 0.8750 - lr: 1.0240e-04
# Epoch 50/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9750
# Epoch 50: ReduceLROnPlateau reducing learning rate to 8.192000095732511e-05.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1367 - accuracy: 0.9750 - val_loss: 0.3204 - val_accuracy: 0.8750 - lr: 1.0240e-04
# Epoch 51/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1353 - accuracy: 0.9750 - val_loss: 0.2775 - val_accuracy: 0.9125 - lr: 8.1920e-05
# Epoch 52/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1336 - accuracy: 0.9750 - val_loss: 0.2774 - val_accuracy: 0.9125 - lr: 8.1920e-05
# Epoch 53/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1327 - accuracy: 0.9750 - val_loss: 0.2875 - val_accuracy: 0.9125 - lr: 8.1920e-05
# Epoch 54/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1318 - accuracy: 0.9750 - val_loss: 0.2944 - val_accuracy: 0.9000 - lr: 8.1920e-05
# Epoch 55/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9750
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.553599960170687e-05.
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1324 - accuracy: 0.9750 - val_loss: 0.2800 - val_accuracy: 0.9125 - lr: 8.1920e-05
# Epoch 56/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1303 - accuracy: 0.9750 - val_loss: 0.2869 - val_accuracy: 0.9125 - lr: 6.5536e-05
# Epoch 57/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1297 - accuracy: 0.9750 - val_loss: 0.2983 - val_accuracy: 0.9000 - lr: 6.5536e-05
# Epoch 58/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1298 - accuracy: 0.9750 - val_loss: 0.2975 - val_accuracy: 0.9000 - lr: 6.5536e-05
# Epoch 59/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1291 - accuracy: 0.9750 - val_loss: 0.3040 - val_accuracy: 0.9000 - lr: 6.5536e-05
# Epoch 60/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9750
# Epoch 60: ReduceLROnPlateau reducing learning rate to 5.242879851721227e-05.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1282 - accuracy: 0.9750 - val_loss: 0.3240 - val_accuracy: 0.8875 - lr: 6.5536e-05
# Epoch 61/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1277 - accuracy: 0.9750 - val_loss: 0.3419 - val_accuracy: 0.8750 - lr: 5.2429e-05
# Epoch 62/200
# 10/10 [==============================] - 5s 484ms/step - loss: 0.1279 - accuracy: 0.9750 - val_loss: 0.3181 - val_accuracy: 0.9000 - lr: 5.2429e-05
# Epoch 63/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1277 - accuracy: 0.9750 - val_loss: 0.2911 - val_accuracy: 0.9125 - lr: 5.2429e-05
# Epoch 64/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1264 - accuracy: 0.9750 - val_loss: 0.2969 - val_accuracy: 0.9000 - lr: 5.2429e-05
# Epoch 65/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9750
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.19430376496166e-05.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1258 - accuracy: 0.9750 - val_loss: 0.3465 - val_accuracy: 0.8625 - lr: 5.2429e-05
# Epoch 66/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1254 - accuracy: 0.9750 - val_loss: 0.3519 - val_accuracy: 0.8625 - lr: 4.1943e-05
# Epoch 67/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1256 - accuracy: 0.9750 - val_loss: 0.3860 - val_accuracy: 0.8625 - lr: 4.1943e-05
# Epoch 68/200
# 10/10 [==============================] - 5s 485ms/step - loss: 0.1421 - accuracy: 0.9688 - val_loss: 0.4890 - val_accuracy: 0.8375 - lr: 4.1943e-05
# Epoch 69/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1189 - accuracy: 0.9750 - val_loss: 0.5170 - val_accuracy: 0.8250 - lr: 4.1943e-05
# Epoch 70/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.9688
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.3554428955540065e-05.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1267 - accuracy: 0.9688 - val_loss: 0.2663 - val_accuracy: 0.9250 - lr: 4.1943e-05
# Epoch 71/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1294 - accuracy: 0.9750 - val_loss: 0.1888 - val_accuracy: 0.9375 - lr: 3.3554e-05
# Epoch 72/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1226 - accuracy: 0.9750 - val_loss: 0.2833 - val_accuracy: 0.9250 - lr: 3.3554e-05
# Epoch 73/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1202 - accuracy: 0.9750 - val_loss: 0.4762 - val_accuracy: 0.8250 - lr: 3.3554e-05
# Epoch 74/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1336 - accuracy: 0.9719 - val_loss: 0.5405 - val_accuracy: 0.8250 - lr: 3.3554e-05
# Epoch 75/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9719
# Epoch 75: ReduceLROnPlateau reducing learning rate to 2.6843542582355442e-05.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1262 - accuracy: 0.9719 - val_loss: 0.4627 - val_accuracy: 0.8250 - lr: 3.3554e-05
# Epoch 76/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1136 - accuracy: 0.9750 - val_loss: 0.3164 - val_accuracy: 0.8750 - lr: 2.6844e-05
# Epoch 77/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1145 - accuracy: 0.9750 - val_loss: 0.3485 - val_accuracy: 0.8625 - lr: 2.6844e-05
# Epoch 78/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1117 - accuracy: 0.9781 - val_loss: 0.4121 - val_accuracy: 0.8250 - lr: 2.6844e-05
# Epoch 79/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1098 - accuracy: 0.9781 - val_loss: 0.4622 - val_accuracy: 0.8250 - lr: 2.6844e-05
# Epoch 80/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9781
# Epoch 80: ReduceLROnPlateau reducing learning rate to 2.1474834647960963e-05.
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1113 - accuracy: 0.9781 - val_loss: 0.3835 - val_accuracy: 0.8375 - lr: 2.6844e-05
# Epoch 81/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1107 - accuracy: 0.9781 - val_loss: 0.3756 - val_accuracy: 0.8500 - lr: 2.1475e-05
# Epoch 82/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1075 - accuracy: 0.9812 - val_loss: 0.4409 - val_accuracy: 0.8250 - lr: 2.1475e-05
# Epoch 83/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1277 - accuracy: 0.9719 - val_loss: 0.4987 - val_accuracy: 0.8250 - lr: 2.1475e-05
# Epoch 84/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1072 - accuracy: 0.9812 - val_loss: 0.4611 - val_accuracy: 0.8250 - lr: 2.1475e-05
# Epoch 85/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9812
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.7179867427330464e-05.
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1060 - accuracy: 0.9812 - val_loss: 0.4859 - val_accuracy: 0.8250 - lr: 2.1475e-05
# Epoch 86/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1110 - accuracy: 0.9781 - val_loss: 0.4587 - val_accuracy: 0.8250 - lr: 1.7180e-05
# Epoch 87/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1064 - accuracy: 0.9812 - val_loss: 0.4733 - val_accuracy: 0.8250 - lr: 1.7180e-05
# Epoch 88/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1081 - accuracy: 0.9812 - val_loss: 0.4221 - val_accuracy: 0.8250 - lr: 1.7180e-05
# Epoch 89/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1053 - accuracy: 0.9812 - val_loss: 0.4163 - val_accuracy: 0.8250 - lr: 1.7180e-05
# Epoch 90/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9812
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.3743893941864372e-05.
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1062 - accuracy: 0.9812 - val_loss: 0.5163 - val_accuracy: 0.8250 - lr: 1.7180e-05
# Epoch 91/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1045 - accuracy: 0.9812 - val_loss: 0.5345 - val_accuracy: 0.8250 - lr: 1.3744e-05
# Epoch 92/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1056 - accuracy: 0.9812 - val_loss: 0.5454 - val_accuracy: 0.8250 - lr: 1.3744e-05
# Epoch 93/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1059 - accuracy: 0.9812 - val_loss: 0.5009 - val_accuracy: 0.8250 - lr: 1.3744e-05
# Epoch 94/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1228 - accuracy: 0.9750 - val_loss: 0.4205 - val_accuracy: 0.8250 - lr: 1.3744e-05
# Epoch 95/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9812
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.0995115007972345e-05.
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1060 - accuracy: 0.9812 - val_loss: 0.4163 - val_accuracy: 0.8250 - lr: 1.3744e-05
# Epoch 96/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1040 - accuracy: 0.9812 - val_loss: 0.4710 - val_accuracy: 0.8250 - lr: 1.0995e-05
# Epoch 97/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1035 - accuracy: 0.9812 - val_loss: 0.5025 - val_accuracy: 0.8250 - lr: 1.0995e-05
# Epoch 98/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1200 - accuracy: 0.9750 - val_loss: 0.4884 - val_accuracy: 0.8250 - lr: 1.0995e-05
# Epoch 99/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1044 - accuracy: 0.9812 - val_loss: 0.4116 - val_accuracy: 0.8375 - lr: 1.0995e-05
# Epoch 100/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9812
# Epoch 100: ReduceLROnPlateau reducing learning rate to 8.796092151897028e-06.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1037 - accuracy: 0.9812 - val_loss: 0.4083 - val_accuracy: 0.8375 - lr: 1.0995e-05
# Epoch 101/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1033 - accuracy: 0.9812 - val_loss: 0.4268 - val_accuracy: 0.8250 - lr: 8.7961e-06
# Epoch 102/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1034 - accuracy: 0.9812 - val_loss: 0.4531 - val_accuracy: 0.8250 - lr: 8.7961e-06
# Epoch 103/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1033 - accuracy: 0.9812 - val_loss: 0.4717 - val_accuracy: 0.8250 - lr: 8.7961e-06
# Epoch 104/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1032 - accuracy: 0.9812 - val_loss: 0.4867 - val_accuracy: 0.8250 - lr: 8.7961e-06
# Epoch 105/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9812
# Epoch 105: ReduceLROnPlateau reducing learning rate to 7.036874012555928e-06.
# 10/10 [==============================] - 5s 484ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.5027 - val_accuracy: 0.8250 - lr: 8.7961e-06
# Epoch 106/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1034 - accuracy: 0.9812 - val_loss: 0.5157 - val_accuracy: 0.8250 - lr: 7.0369e-06
# Epoch 107/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1051 - accuracy: 0.9812 - val_loss: 0.4928 - val_accuracy: 0.8250 - lr: 7.0369e-06
# Epoch 108/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1029 - accuracy: 0.9812 - val_loss: 0.4725 - val_accuracy: 0.8250 - lr: 7.0369e-06
# Epoch 109/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1036 - accuracy: 0.9812 - val_loss: 0.4893 - val_accuracy: 0.8250 - lr: 7.0369e-06
# Epoch 110/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9812
# Epoch 110: ReduceLROnPlateau reducing learning rate to 5.629499355563894e-06.
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1043 - accuracy: 0.9812 - val_loss: 0.4731 - val_accuracy: 0.8250 - lr: 7.0369e-06
# Epoch 111/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1026 - accuracy: 0.9812 - val_loss: 0.4365 - val_accuracy: 0.8375 - lr: 5.6295e-06
# Epoch 112/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.4394 - val_accuracy: 0.8375 - lr: 5.6295e-06
# Epoch 113/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1039 - accuracy: 0.9812 - val_loss: 0.4406 - val_accuracy: 0.8375 - lr: 5.6295e-06
# Epoch 114/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1029 - accuracy: 0.9812 - val_loss: 0.4284 - val_accuracy: 0.8375 - lr: 5.6295e-06
# Epoch 115/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9812
# Epoch 115: ReduceLROnPlateau reducing learning rate to 4.503599484451115e-06.
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1032 - accuracy: 0.9812 - val_loss: 0.4296 - val_accuracy: 0.8375 - lr: 5.6295e-06
# Epoch 116/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1026 - accuracy: 0.9812 - val_loss: 0.4426 - val_accuracy: 0.8375 - lr: 4.5036e-06
# Epoch 117/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1025 - accuracy: 0.9812 - val_loss: 0.4498 - val_accuracy: 0.8250 - lr: 4.5036e-06
# Epoch 118/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1024 - accuracy: 0.9812 - val_loss: 0.4563 - val_accuracy: 0.8250 - lr: 4.5036e-06
# Epoch 119/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1043 - accuracy: 0.9812 - val_loss: 0.4279 - val_accuracy: 0.8375 - lr: 4.5036e-06
# Epoch 120/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9750
# Epoch 120: ReduceLROnPlateau reducing learning rate to 3.602879587560892e-06.
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1152 - accuracy: 0.9750 - val_loss: 0.3263 - val_accuracy: 0.8875 - lr: 4.5036e-06
# Epoch 121/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1038 - accuracy: 0.9812 - val_loss: 0.3149 - val_accuracy: 0.9000 - lr: 3.6029e-06
# Epoch 122/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1041 - accuracy: 0.9812 - val_loss: 0.3178 - val_accuracy: 0.9000 - lr: 3.6029e-06
# Epoch 123/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1032 - accuracy: 0.9812 - val_loss: 0.3261 - val_accuracy: 0.8875 - lr: 3.6029e-06
# Epoch 124/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1028 - accuracy: 0.9812 - val_loss: 0.3351 - val_accuracy: 0.8875 - lr: 3.6029e-06
# Epoch 125/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9781
# Epoch 125: ReduceLROnPlateau reducing learning rate to 2.882303670048714e-06.
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1066 - accuracy: 0.9781 - val_loss: 0.3445 - val_accuracy: 0.8875 - lr: 3.6029e-06
# Epoch 126/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1026 - accuracy: 0.9812 - val_loss: 0.3398 - val_accuracy: 0.8875 - lr: 2.8823e-06
# Epoch 127/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1052 - accuracy: 0.9781 - val_loss: 0.3294 - val_accuracy: 0.8875 - lr: 2.8823e-06
# Epoch 128/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.3219 - val_accuracy: 0.9000 - lr: 2.8823e-06
# Epoch 129/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1082 - accuracy: 0.9781 - val_loss: 0.3044 - val_accuracy: 0.9125 - lr: 2.8823e-06
# Epoch 130/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9812
# Epoch 130: ReduceLROnPlateau reducing learning rate to 2.3058430087985473e-06.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1034 - accuracy: 0.9812 - val_loss: 0.3027 - val_accuracy: 0.9125 - lr: 2.8823e-06
# Epoch 131/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1041 - accuracy: 0.9812 - val_loss: 0.3067 - val_accuracy: 0.9125 - lr: 2.3058e-06
# Epoch 132/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1025 - accuracy: 0.9812 - val_loss: 0.3130 - val_accuracy: 0.9000 - lr: 2.3058e-06
# Epoch 133/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.3167 - val_accuracy: 0.9000 - lr: 2.3058e-06
# Epoch 134/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1027 - accuracy: 0.9812 - val_loss: 0.3239 - val_accuracy: 0.9000 - lr: 2.3058e-06
# Epoch 135/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9812
# Epoch 135: ReduceLROnPlateau reducing learning rate to 1.8446744434186257e-06.
# 10/10 [==============================] - 5s 485ms/step - loss: 0.1026 - accuracy: 0.9812 - val_loss: 0.3303 - val_accuracy: 0.8875 - lr: 2.3058e-06
# Epoch 136/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1027 - accuracy: 0.9812 - val_loss: 0.3321 - val_accuracy: 0.8875 - lr: 1.8447e-06
# Epoch 137/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3344 - val_accuracy: 0.8875 - lr: 1.8447e-06
# Epoch 138/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3362 - val_accuracy: 0.8875 - lr: 1.8447e-06
# Epoch 139/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1025 - accuracy: 0.9812 - val_loss: 0.3374 - val_accuracy: 0.8875 - lr: 1.8447e-06
# Epoch 140/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9812
# Epoch 140: ReduceLROnPlateau reducing learning rate to 1.4757395547349006e-06.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1033 - accuracy: 0.9812 - val_loss: 0.3436 - val_accuracy: 0.8875 - lr: 1.8447e-06
# Epoch 141/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3476 - val_accuracy: 0.8875 - lr: 1.4757e-06
# Epoch 142/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3497 - val_accuracy: 0.8875 - lr: 1.4757e-06
# Epoch 143/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3507 - val_accuracy: 0.8875 - lr: 1.4757e-06
# Epoch 144/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1028 - accuracy: 0.9812 - val_loss: 0.3520 - val_accuracy: 0.8875 - lr: 1.4757e-06
# Epoch 145/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9812
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.1805916074081326e-06.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1035 - accuracy: 0.9812 - val_loss: 0.3530 - val_accuracy: 0.8875 - lr: 1.4757e-06
# Epoch 146/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3519 - val_accuracy: 0.8875 - lr: 1.1806e-06
# Epoch 147/200
# 10/10 [==============================] - 5s 477ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3519 - val_accuracy: 0.8875 - lr: 1.1806e-06
# Epoch 148/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1054 - accuracy: 0.9781 - val_loss: 0.3455 - val_accuracy: 0.8875 - lr: 1.1806e-06
# Epoch 149/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1023 - accuracy: 0.9812 - val_loss: 0.3396 - val_accuracy: 0.8875 - lr: 1.1806e-06
# Epoch 150/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9812
# Epoch 150: ReduceLROnPlateau reducing learning rate to 9.44473322306294e-07.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1025 - accuracy: 0.9812 - val_loss: 0.3384 - val_accuracy: 0.8875 - lr: 1.1806e-06
# Epoch 151/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1019 - accuracy: 0.9812 - val_loss: 0.3386 - val_accuracy: 0.8875 - lr: 9.4447e-07
# Epoch 152/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1023 - accuracy: 0.9812 - val_loss: 0.3397 - val_accuracy: 0.8875 - lr: 9.4447e-07
# Epoch 153/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3412 - val_accuracy: 0.8875 - lr: 9.4447e-07
# Epoch 154/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1024 - accuracy: 0.9812 - val_loss: 0.3433 - val_accuracy: 0.8875 - lr: 9.4447e-07
# Epoch 155/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9812
# Epoch 155: ReduceLROnPlateau reducing learning rate to 7.555786396551412e-07.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3446 - val_accuracy: 0.8875 - lr: 9.4447e-07
# Epoch 156/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1019 - accuracy: 0.9812 - val_loss: 0.3452 - val_accuracy: 0.8875 - lr: 7.5558e-07
# Epoch 157/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3460 - val_accuracy: 0.8875 - lr: 7.5558e-07
# Epoch 158/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3467 - val_accuracy: 0.8875 - lr: 7.5558e-07
# Epoch 159/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3476 - val_accuracy: 0.8875 - lr: 7.5558e-07
# Epoch 160/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9812
# Epoch 160: ReduceLROnPlateau reducing learning rate to 6.044629117241129e-07.
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1019 - accuracy: 0.9812 - val_loss: 0.3483 - val_accuracy: 0.8875 - lr: 7.5558e-07
# Epoch 161/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1027 - accuracy: 0.9812 - val_loss: 0.3489 - val_accuracy: 0.8875 - lr: 6.0446e-07
# Epoch 162/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3495 - val_accuracy: 0.8875 - lr: 6.0446e-07
# Epoch 163/200
# 10/10 [==============================] - 5s 483ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3504 - val_accuracy: 0.8875 - lr: 6.0446e-07
# Epoch 164/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1023 - accuracy: 0.9812 - val_loss: 0.3512 - val_accuracy: 0.8875 - lr: 6.0446e-07
# Epoch 165/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9812
# Epoch 165: ReduceLROnPlateau reducing learning rate to 4.835703293792904e-07.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1019 - accuracy: 0.9812 - val_loss: 0.3525 - val_accuracy: 0.8875 - lr: 6.0446e-07
# Epoch 166/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1028 - accuracy: 0.9812 - val_loss: 0.3538 - val_accuracy: 0.8875 - lr: 4.8357e-07
# Epoch 167/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3552 - val_accuracy: 0.8875 - lr: 4.8357e-07
# Epoch 168/200
# 10/10 [==============================] - 5s 474ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3557 - val_accuracy: 0.8875 - lr: 4.8357e-07
# Epoch 169/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3559 - val_accuracy: 0.8875 - lr: 4.8357e-07
# Epoch 170/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9812
# Epoch 170: ReduceLROnPlateau reducing learning rate to 3.8685625440848527e-07.
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1029 - accuracy: 0.9812 - val_loss: 0.3535 - val_accuracy: 0.8875 - lr: 4.8357e-07
# Epoch 171/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3528 - val_accuracy: 0.8875 - lr: 3.8686e-07
# Epoch 172/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3526 - val_accuracy: 0.8875 - lr: 3.8686e-07
# Epoch 173/200
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3526 - val_accuracy: 0.8875 - lr: 3.8686e-07
# Epoch 174/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1028 - accuracy: 0.9812 - val_loss: 0.3521 - val_accuracy: 0.8875 - lr: 3.8686e-07
# Epoch 175/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9812
# Epoch 175: ReduceLROnPlateau reducing learning rate to 3.094849944318412e-07.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3519 - val_accuracy: 0.8875 - lr: 3.8686e-07
# Epoch 176/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3519 - val_accuracy: 0.8875 - lr: 3.0948e-07
# Epoch 177/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3521 - val_accuracy: 0.8875 - lr: 3.0948e-07
# Epoch 178/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3525 - val_accuracy: 0.8875 - lr: 3.0948e-07
# Epoch 179/200
# 10/10 [==============================] - 5s 486ms/step - loss: 0.1210 - accuracy: 0.9750 - val_loss: 0.3523 - val_accuracy: 0.8875 - lr: 3.0948e-07
# Epoch 180/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9812
# Epoch 180: ReduceLROnPlateau reducing learning rate to 2.4758799099799944e-07.
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3522 - val_accuracy: 0.8875 - lr: 3.0948e-07
# Epoch 181/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3525 - val_accuracy: 0.8875 - lr: 2.4759e-07
# Epoch 182/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.3519 - val_accuracy: 0.8875 - lr: 2.4759e-07
# Epoch 183/200
# 10/10 [==============================] - 5s 481ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3518 - val_accuracy: 0.8875 - lr: 2.4759e-07
# Epoch 184/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1022 - accuracy: 0.9812 - val_loss: 0.3511 - val_accuracy: 0.8875 - lr: 2.4759e-07
# Epoch 185/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9812
# Epoch 185: ReduceLROnPlateau reducing learning rate to 1.9807039279839956e-07.
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1021 - accuracy: 0.9812 - val_loss: 0.3510 - val_accuracy: 0.8875 - lr: 2.4759e-07
# Epoch 186/200
# 10/10 [==============================] - 5s 476ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3509 - val_accuracy: 0.8875 - lr: 1.9807e-07
# Epoch 187/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3509 - val_accuracy: 0.8875 - lr: 1.9807e-07
# Epoch 188/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1020 - accuracy: 0.9812 - val_loss: 0.3510 - val_accuracy: 0.8875 - lr: 1.9807e-07
# Epoch 189/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3513 - val_accuracy: 0.8875 - lr: 1.9807e-07
# Epoch 190/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9812
# Epoch 190: ReduceLROnPlateau reducing learning rate to 1.584563165124564e-07.
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1031 - accuracy: 0.9812 - val_loss: 0.3513 - val_accuracy: 0.8875 - lr: 1.9807e-07
# Epoch 191/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1124 - accuracy: 0.9750 - val_loss: 0.3482 - val_accuracy: 0.8875 - lr: 1.5846e-07
# Epoch 192/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3469 - val_accuracy: 0.8875 - lr: 1.5846e-07
# Epoch 193/200
# 10/10 [==============================] - 5s 476ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3465 - val_accuracy: 0.8875 - lr: 1.5846e-07
# Epoch 194/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3464 - val_accuracy: 0.8875 - lr: 1.5846e-07
# Epoch 195/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9812
# Epoch 195: ReduceLROnPlateau reducing learning rate to 1.267650532099651e-07.
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3464 - val_accuracy: 0.8875 - lr: 1.5846e-07
# Epoch 196/200
# 10/10 [==============================] - 5s 480ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3464 - val_accuracy: 0.8875 - lr: 1.2677e-07
# Epoch 197/200
# 10/10 [==============================] - 5s 475ms/step - loss: 0.1018 - accuracy: 0.9812 - val_loss: 0.3464 - val_accuracy: 0.8875 - lr: 1.2677e-07
# Epoch 198/200
# 10/10 [==============================] - 5s 479ms/step - loss: 0.1017 - accuracy: 0.9812 - val_loss: 0.3465 - val_accuracy: 0.8875 - lr: 1.2677e-07
# Epoch 199/200
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1042 - accuracy: 0.9812 - val_loss: 0.3474 - val_accuracy: 0.8875 - lr: 1.2677e-07
# Epoch 200/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9750
# Epoch 200: ReduceLROnPlateau reducing learning rate to 1.0141204711544561e-07.
# 10/10 [==============================] - 5s 476ms/step - loss: 0.1188 - accuracy: 0.9750 - val_loss: 0.3472 - val_accuracy: 0.8875 - lr: 1.2677e-07

# %%
### Plot train and validation curves
loss = ViT_Train.history['loss']
v_loss = ViT_Train.history['val_loss']

acc = ViT_Train.history['accuracy'] 
v_acc = ViT_Train.history['val_accuracy']


epochs = range(len(loss))

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.yscale('log')
plt.plot(epochs, loss, linestyle='--', linewidth=3, color='orange', alpha=0.7, label='Train Loss')
plt.plot(epochs, v_loss, linestyle='-.', linewidth=2, color='lime', alpha=0.8, label='Valid Loss')
# plt.ylim(0.3, 100)
plt.xlabel('Epochs', fontsize=11)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=12)
plt.subplot(1, 2, 2)
plt.plot(epochs, acc, linestyle='--', linewidth=3, color='orange', alpha=0.7, label='Train Acc')
plt.plot(epochs, v_acc, linestyle='-.', linewidth=2, color='lime', alpha=0.8, label='Valid Acc') 
plt.xlabel('Epochs', fontsize=11)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=12)
plt.tight_layout()
# plt.savefig('/content/gdrive/My Drive/Colab Notebooks/resnet/train_acc.png', dpi=250)
plt.show()

# %%
#ViT_model.save(NAME)
